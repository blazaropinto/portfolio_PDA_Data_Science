# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('2106-Market_Research_Raw_Data_cleaned for analysis_cleaned_Jay.xlsx', 
                   sheet_name='Cleaned with Questions', header=0)
df.head()
# Out:
#   Question Weight What is your age? What is your gender?  \
# 0         1.05932           25 – 34               Female
# 1         0.74047           45 – 54                 Male
# 2         0.74047           45 – 54                 Male
# 3         1.08698           35 – 44                 Male
# 4          1.0198           65 – 74                 Male
#
#   space for walking/cycling, restricting parking/closing streets near schools  \
# 0                                            Support
# 1                                            Support
# 2                                   Strongly support
# 3                                   Strongly support
# 4                                            Support
#
#   New protected cycle lanes on main roads  \
# 0                                 Support
# 1                                 Support
# 2                        Strongly support
# 3                        Strongly support
# 4                        Strongly support
#
#   Space in shopping streets for walking and/or cycling  \
# 0                                            Support
# 1                                            Support
# 2                                   Strongly support
# 3                                   Strongly support
# 4                                            Support
#
#   Space in city centre for walking and/or cycling  \
# 0                                         Support
# 1                                Strongly support
# 2                                Strongly support
# 3                                Strongly support
# 4                                         Neutral
#
#   Connecting existing walking/cycling routes used for leisure, by closing some roads to cars and/or providing protected space for walking and cycling on roads.  \
# 0                                            Support
# 1                                            Support
# 2                                   Strongly support
# 3                                   Strongly support
# 4                                             Oppose
#
#   New signed ‘quiet connections’ for day to day cycling, with road closures to reduce traffic.  \
# 0                                            Support
# 1                                            Support
# 2                                   Strongly support
# 3                                   Strongly support
# 4                                            Neutral
#
#     Area  \
# 0  North
# 1   East
# 2  North
# 3  South
# 4  South
#
#   how many cars or vans (own or company cars/vans) are available to members of your household?
# 0                                                  1
# 1                                               None
# 2                                                  1
# 3                                               None
# 4                                                  1

# %%
df.set_index('Question Weight', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1048574 entries, 1.05932 to Question Weight
# Data columns (total 10 columns):
#  #   Column                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                         --------------  -----
#  0   What is your age?                                                                                                                                              585 non-null    object
#  1   What is your gender?                                                                                                                                           585 non-null    object
#  2   space for walking/cycling, restricting parking/closing streets near schools                                                                                    585 non-null    object
#  3   New protected cycle lanes on main roads                                                                                                                        585 non-null    object
#  4   Space in shopping streets for walking and/or cycling                                                                                                           585 non-null    object
#  5   Space in city centre for walking and/or cycling                                                                                                                585 non-null    object
#  6   Connecting existing walking/cycling routes used for leisure, by closing some roads to cars and/or providing protected space for walking and cycling on roads.  585 non-null    object
#  7   New signed ‘quiet connections’ for day to day cycling, with road closures to reduce traffic.                                                                   585 non-null    object
#  8   Area                                                                                                                                                           585 non-null    object
#  9   how many cars or vans (own or company cars/vans) are available to members of your household?                                                                   585 non-null    object
# dtypes: object(10)
# memory usage: 88.0+ MB

# %%
for col in df.columns:
    df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1048574 entries, 1.05932 to Question Weight
# Data columns (total 10 columns):
#  #   Column                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                         --------------  -----
#  0   What is your age?                                                                                                                                              585 non-null    category
#  1   What is your gender?                                                                                                                                           585 non-null    category
#  2   space for walking/cycling, restricting parking/closing streets near schools                                                                                    585 non-null    category
#  3   New protected cycle lanes on main roads                                                                                                                        585 non-null    category
#  4   Space in shopping streets for walking and/or cycling                                                                                                           585 non-null    category
#  5   Space in city centre for walking and/or cycling                                                                                                                585 non-null    category
#  6   Connecting existing walking/cycling routes used for leisure, by closing some roads to cars and/or providing protected space for walking and cycling on roads.  585 non-null    category
#  7   New signed ‘quiet connections’ for day to day cycling, with road closures to reduce traffic.                                                                   585 non-null    category
#  8   Area                                                                                                                                                           585 non-null    category
#  9   how many cars or vans (own or company cars/vans) are available to members of your household?                                                                   585 non-null    category
# dtypes: category(10)
# memory usage: 18.0+ MB

# %%
df.Area.value_counts()
# Out:
# North      152
# South      128
# East       127
# West       112
# Central     64
# VQ39         1
# Area         1
# Name: Area, dtype: int64

# %%
df[df.Area == 'VQ39']
# Out:
#                 What is your age? What is your gender?  \
# Question Weight
# Weight                        SQ3                  SQ4
#
#                 space for walking/cycling, restricting parking/closing streets near schools  \
# Question Weight
# Weight                                                         Q4a
#
#                 New protected cycle lanes on main roads  \
# Question Weight
# Weight                                              Q4b
#
#                 Space in shopping streets for walking and/or cycling  \
# Question Weight
# Weight                                                         Q4c
#
#                 Space in city centre for walking and/or cycling  \
# Question Weight
# Weight                                                      Q4d
#
#                 Connecting existing walking/cycling routes used for leisure, by closing some roads to cars and/or providing protected space for walking and cycling on roads.  \
# Question Weight
# Weight                                                         Q4e
#
#                 New signed ‘quiet connections’ for day to day cycling, with road closures to reduce traffic.  \
# Question Weight
# Weight                                                         Q4f
#
#                  Area  \
# Question Weight
# Weight           VQ39
#
#                 how many cars or vans (own or company cars/vans) are available to members of your household?
# Question Weight
# Weight                                                         Q40

# %%
codes = []

for code in df.loc['Weight']:
    codes.append(code)
codes
# Out:
# ['SQ3', 'SQ4', 'Q4a', 'Q4b', 'Q4c', 'Q4d', 'Q4e', 'Q4f', 'VQ39', 'Q40']

# %%
df.replace(codes, np.nan, inplace=True)
df.replace(df.columns, np.nan, inplace=True)
df = df.dropna()
df.Area.value_counts()
# Out:
# North      152
# South      128
# East       127
# West       112
# Central     64
# Name: Area, dtype: int64

# %%
df.head()
# Out:
#                 What is your age? What is your gender?  \
# Question Weight
# 1.05932                   25 – 34               Female
# 0.74047                   45 – 54                 Male
# 0.74047                   45 – 54                 Male
# 1.08698                   35 – 44                 Male
# 1.01980                   65 – 74                 Male
#
#                 space for walking/cycling, restricting parking/closing streets near schools  \
# Question Weight
# 1.05932                                                    Support
# 0.74047                                                    Support
# 0.74047                                           Strongly support
# 1.08698                                           Strongly support
# 1.01980                                                    Support
#
#                 New protected cycle lanes on main roads  \
# Question Weight
# 1.05932                                         Support
# 0.74047                                         Support
# 0.74047                                Strongly support
# 1.08698                                Strongly support
# 1.01980                                Strongly support
#
#                 Space in shopping streets for walking and/or cycling  \
# Question Weight
# 1.05932                                                    Support
# 0.74047                                                    Support
# 0.74047                                           Strongly support
# 1.08698                                           Strongly support
# 1.01980                                                    Support
#
#                 Space in city centre for walking and/or cycling  \
# Question Weight
# 1.05932                                                 Support
# 0.74047                                        Strongly support
# 0.74047                                        Strongly support
# 1.08698                                        Strongly support
# 1.01980                                                 Neutral
#
#                 Connecting existing walking/cycling routes used for leisure, by closing some roads to cars and/or providing protected space for walking and cycling on roads.  \
# Question Weight
# 1.05932                                                    Support
# 0.74047                                                    Support
# 0.74047                                           Strongly support
# 1.08698                                           Strongly support
# 1.01980                                                     Oppose
#
#                 New signed ‘quiet connections’ for day to day cycling, with road closures to reduce traffic.  \
# Question Weight
# 1.05932                                                    Support
# 0.74047                                                    Support
# 0.74047                                           Strongly support
# 1.08698                                           Strongly support
# 1.01980                                                    Neutral
#
#                   Area  \
# Question Weight
# 1.05932          North
# 0.74047           East
# 0.74047          North
# 1.08698          South
# 1.01980          South
#
#                 how many cars or vans (own or company cars/vans) are available to members of your household?
# Question Weight
# 1.05932                                                          1
# 0.74047                                                       None
# 0.74047                                                          1
# 1.08698                                                       None
# 1.01980                                                          1

# %%
df[df['What is your age?'] == 'What is your age?']
# Out:
# Empty DataFrame
# Columns: [What is your age?, What is your gender?, space for walking/cycling, restricting parking/closing streets near schools, New protected cycle lanes on main roads, Space in shopping streets for walking and/or cycling, Space in city centre for walking and/or cycling, Connecting existing walking/cycling routes used for leisure, by closing some roads to cars and/or providing protected space for walking and cycling on roads., New signed ‘quiet connections’ for day to day cycling, with road closures to reduce traffic., Area, how many cars or vans (own or company cars/vans) are available to members of your household?]
# Index: []

# %%
df['What is your age?'].value_counts()
# Out:
# 35 – 44        122
# 55 – 64        115
# 45 – 54        108
# 25 – 34         96
# 65 – 74         84
# 16 – 24         44
# 75 and over     14
# Name: What is your age?, dtype: int64

# %%
for col in df.columns:
    print(col)
    plt.barh(df[col].value_counts().index, df[col].value_counts())
    plt.show()
# Out:
# What is your age?
# What is your gender?
# space for walking/cycling, restricting parking/closing streets near schools
# New protected cycle lanes on main roads
# Space in shopping streets for walking and/or cycling
# Space in city centre for walking and/or cycling
# Connecting existing walking/cycling routes used for leisure, by closing some roads to cars and/or providing protected space for walking and cycling on roads.
# New signed ‘quiet connections’ for day to day cycling, with road closures to reduce traffic.
# Area
# how many cars or vans (own or company cars/vans) are available to members of your household?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2467                 try:
# -> 2468                     bottom = y - height / 2
#    2469                 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-a521f3ba5455> in <module>
#       1 for col in df.columns:
#       2     print(col)
# ----> 3     plt.barh(df[col].value_counts().index, df[col].value_counts())
#       4     plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2500 @_copy_docstring_and_deprecators(Axes.barh)
#    2501 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2502     return gca().barh(
#    2503         y, width, height=height, left=left, align=align, **kwargs)
#    2504
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2628         """
#    2629         kwargs.setdefault('orientation', 'horizontal')
# -> 2630         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2631                            align=align, **kwargs)
#    2632         return patches
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2468                     bottom = y - height / 2
#    2469                 except TypeError as e:
# -> 2470                     raise TypeError(f'the dtypes of parameters y ({y.dtype}) '
#    2471                                     f'and height ({height.dtype}) '
#    2472                                     f'are incompatible') from e
#
# TypeError: the dtypes of parameters y (object) and height (float64) are incompatible

# %%
for col in df.columns:
    print(col)
    plt.pie(df[col].value_counts(), labels=df[col].value_counts().index)
    plt.show()
# Out:
# What is your age?
# What is your gender?
# space for walking/cycling, restricting parking/closing streets near schools
# New protected cycle lanes on main roads
# Space in shopping streets for walking and/or cycling
# Space in city centre for walking and/or cycling
# Connecting existing walking/cycling routes used for leisure, by closing some roads to cars and/or providing protected space for walking and cycling on roads.
# New signed ‘quiet connections’ for day to day cycling, with road closures to reduce traffic.
# Area
# how many cars or vans (own or company cars/vans) are available to members of your household?
